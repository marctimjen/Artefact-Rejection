# %%
import mne
import matplotlib.pyplot as plt

# %%
file_dir = "C:/Users/Bruger/Documents/GitHub/edf/01_tcp_ar/004/00000458/s004_2003_02_12/00000458_s004_t001.edf"

file = mne.io.read_raw_edf(file_dir, preload=True)
# Out:
# Extracting EDF parameters from C:\Users\Bruger\Documents\GitHub\edf\01_tcp_ar\004\00000458\s004_2003_02_12\00000458_s004_t001.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 495599  =      0.000 ...  1238.997 secs...

# %%
# %matplotlib
file.plot(start = 198)
# Out:
# Using matplotlib backend: Qt5Agg
# <MNEBrowseFigure size 1600x1050 with 4 Axes>
# Channels marked as bad: none

# %%
# %matplotlib
file.plot(start = 240)
# Out:
# Using matplotlib backend: Qt5Agg
# <MNEBrowseFigure size 1600x1050 with 4 Axes>
# Channels marked as bad: none

# %%
# %matplotlib
file.plot(start = 314)
# Out:
# Using matplotlib backend: Qt5Agg
# <MNEBrowseFigure size 1600x1050 with 4 Axes>
# Channels marked as bad: none

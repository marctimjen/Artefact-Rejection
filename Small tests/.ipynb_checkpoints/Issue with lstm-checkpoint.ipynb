# %%
import neptune.new as neptune
import os
import torch.nn as nn
import torch
import torch.nn.functional as F
from torch.optim import SGD, Adam
from torch.utils.data import DataLoader, random_split
from torch.optim.lr_scheduler import LambdaLR
import torch.multiprocessing as mp
import numpy as np
import random
import math

import sys
sys.path.append("..") # adds higher directory to python modules path

from LoaderPACK.LSTM_net import LSTM_net

# %%
ind = torch.load(r"C:\Users\Marc\Desktop\Wierd output\ind.pt").to("cpu")

# %%
ind.shape
# Out:
# torch.Size([10, 1, 60000])

# %%
ind
# Out:
# tensor([[[  5.7873,   2.8735,   4.3204,  ...,   1.8193,  -0.2992,  -0.6758]],
#
#         [[  4.0954,   8.0991,   6.5922,  ...,  26.7045,  24.6322,  19.7239]],
#
#         [[  7.6339,  10.7983,  11.2701,  ...,  -2.8396,  -6.4964,  -8.3752]],
#
#         ...,
#
#         [[ -7.6907,   0.3859,  22.7656,  ...,  -8.1175, -17.1491, -16.2881]],
#
#         [[ 21.8641,  12.8339,  16.2406,  ...,  -4.5149,  -7.0672,  -8.2953]],
#
#         [[ -0.3570,   0.5192,   1.3458,  ...,  -2.6831,  -9.9697,   5.9507]]])

# %%
batch_size = 10
device = "cpu"

model = LSTM_net(batch_size=batch_size, device=device).to(device)

# %%
out = model(ind)

# %%
out
# Out:
# tensor([[[0.2653, 0.2677, 0.2697,  ..., 0.2744, 0.2758, 0.2774],
#          [0.7347, 0.7323, 0.7303,  ..., 0.7256, 0.7242, 0.7226]],
#
#         [[0.2651, 0.2682, 0.2704,  ..., 0.2756, 0.2765, 0.2773],
#          [0.7349, 0.7318, 0.7296,  ..., 0.7244, 0.7235, 0.7227]],
#
#         [[0.2656, 0.2682, 0.2702,  ..., 0.2798, 0.2807, 0.2803],
#          [0.7344, 0.7318, 0.7298,  ..., 0.7202, 0.7193, 0.7197]],
#
#         ...,
#
#         [[0.2679, 0.2696, 0.2729,  ..., 0.2803, 0.2800, 0.2795],
#          [0.7321, 0.7304, 0.7271,  ..., 0.7197, 0.7200, 0.7205]],
#
#         [[0.2664, 0.2688, 0.2706,  ..., 0.2810, 0.2814, 0.2806],
#          [0.7336, 0.7312, 0.7294,  ..., 0.7190, 0.7186, 0.7194]],
#
#         [[0.2642, 0.2664, 0.2681,  ..., 0.2803, 0.2803, 0.2784],
#          [0.7358, 0.7336, 0.7319,  ..., 0.7197, 0.7197, 0.7216]]],
#        grad_fn=<SoftmaxBackward0>)

# %%
out.shape
# Out:
# torch.Size([10, 2, 60000])

# %%
for i in model.parameters():
    print(i)
# Out:
# Parameter containing:
# tensor([[ 0.2221],
#         [ 0.2588],
#         [ 0.1270],
#         [-0.1091],
#         [-0.3500],
#         [ 0.1029],
#         [ 0.0132],
#         [-0.1381],
#         [-0.0143],
#         [ 0.0521],
#         [-0.3621],
#         [-0.2979],
#         [ 0.3028],
#         [ 0.4220],
#         [ 0.0454],
#         [-0.2051],
#         [-0.4214],
#         [ 0.4318],
#         [ 0.0836],
#         [-0.4423]], requires_grad=True)
# Parameter containing:
# tensor([[-0.4256],
#         [-0.1324],
#         [ 0.0218],
#         [ 0.1252],
#         [-0.2245],
#         [-0.3715],
#         [-0.4279],
#         [ 0.4228],
#         [ 0.4421],
#         [-0.1609],
#         [ 0.0845],
#         [ 0.3892],
#         [-0.3774],
#         [ 0.4220],
#         [ 0.0448],
#         [-0.3043],
#         [ 0.3284],
#         [ 0.1763],
#         [-0.0301],
#         [-0.0333]], requires_grad=True)
# Parameter containing:
# tensor([-0.1875,  0.3616,  0.3281,  0.1931,  0.2074,  0.3885,  0.2878, -0.2725,
#         -0.1815, -0.0606,  0.4420, -0.3877,  0.2990, -0.2801, -0.2000, -0.2391,
#          0.2731,  0.2885,  0.1954,  0.1564], requires_grad=True)
# Parameter containing:
# tensor([-0.4376, -0.0010, -0.2425, -0.4446, -0.3523, -0.2102,  0.1655,  0.0543,
#          0.1382,  0.3536,  0.4403,  0.0936, -0.2354,  0.0756, -0.3151,  0.1750,
#         -0.0743,  0.2093,  0.1241, -0.2037], requires_grad=True)
# Parameter containing:
# tensor([[ 0.3156, -0.0815, -0.1560,  0.2332,  0.3181]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.3260],
#         [-0.2770],
#         [-0.0874],
#         [ 0.0075],
#         [ 0.0216],
#         [-0.0035],
#         [-0.4403],
#         [-0.1371],
#         [ 0.1904],
#         [-0.2989],
#         [-0.4357],
#         [ 0.4077],
#         [-0.3528],
#         [ 0.3193],
#         [ 0.3506],
#         [-0.1737],
#         [ 0.3980],
#         [-0.3312],
#         [ 0.1695],
#         [ 0.4284]], requires_grad=True)
# Parameter containing:
# tensor([[-0.2565],
#         [-0.4036],
#         [ 0.4069],
#         [ 0.3043],
#         [ 0.3958],
#         [ 0.1350],
#         [ 0.0711],
#         [-0.4369],
#         [ 0.2134],
#         [-0.0445],
#         [ 0.0471],
#         [ 0.0963],
#         [ 0.0604],
#         [ 0.0824],
#         [-0.3026],
#         [ 0.4256],
#         [ 0.1975],
#         [ 0.1584],
#         [ 0.3437],
#         [ 0.3767]], requires_grad=True)
# Parameter containing:
# tensor([-0.2224,  0.3459, -0.0460, -0.2184, -0.3200, -0.1052,  0.4238, -0.2136,
#         -0.2529, -0.0302, -0.0902,  0.1566,  0.3260, -0.4131,  0.3818,  0.1263,
#          0.1889,  0.1432,  0.1042, -0.2112], requires_grad=True)
# Parameter containing:
# tensor([-0.0560, -0.3745,  0.3003,  0.1611, -0.2537, -0.0845, -0.4361,  0.1600,
#         -0.2017, -0.1870, -0.1460,  0.0179,  0.4324,  0.0257,  0.2804, -0.0712,
#         -0.4011, -0.2639,  0.3592,  0.4199], requires_grad=True)
# Parameter containing:
# tensor([[-0.2856,  0.1609,  0.4016,  0.1487,  0.2291]], requires_grad=True)
# Parameter containing:
# tensor([[-0.1897,  0.0927],
#         [ 0.0996, -0.2305],
#         [-0.0250,  0.2230],
#         [ 0.0852, -0.0991],
#         [ 0.2443, -0.0700],
#         [ 0.2311,  0.3847],
#         [-0.0056,  0.3978],
#         [-0.1374, -0.2162],
#         [ 0.4170, -0.1833],
#         [ 0.0394,  0.1428],
#         [-0.2411,  0.2639],
#         [-0.0522,  0.0356],
#         [-0.0834,  0.2618],
#         [ 0.2543,  0.4403],
#         [ 0.0422, -0.1265],
#         [ 0.4217, -0.0429],
#         [-0.3072, -0.0895],
#         [ 0.3046, -0.3449],
#         [-0.0612,  0.0378],
#         [-0.2661, -0.4203]], requires_grad=True)
# Parameter containing:
# tensor([[-0.2981],
#         [ 0.0981],
#         [-0.0879],
#         [-0.0735],
#         [ 0.2621],
#         [ 0.0691],
#         [ 0.3546],
#         [ 0.3539],
#         [ 0.2047],
#         [-0.1191],
#         [ 0.2275],
#         [ 0.3187],
#         [-0.1622],
#         [ 0.0946],
#         [ 0.2271],
#         [ 0.0316],
#         [-0.3012],
#         [ 0.2408],
#         [ 0.2310],
#         [ 0.2631]], requires_grad=True)
# Parameter containing:
# tensor([-0.3377, -0.0802, -0.1430,  0.0938, -0.0735,  0.2616, -0.1652, -0.3622,
#         -0.0048, -0.1698,  0.2608,  0.0901,  0.0093, -0.3440,  0.1008,  0.1792,
#          0.1217, -0.1396,  0.1978,  0.0895], requires_grad=True)
# Parameter containing:
# tensor([-0.1392,  0.3129,  0.1727, -0.3789, -0.1939, -0.1083, -0.0677, -0.3675,
#         -0.0327, -0.4428,  0.1990, -0.0025,  0.3546, -0.3961,  0.4023, -0.0045,
#         -0.2470,  0.1004,  0.1967, -0.3750], requires_grad=True)
# Parameter containing:
# tensor([[ 0.0979, -0.2261, -0.2591, -0.3465, -0.3895]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.2789,  0.2837],
#         [ 0.0160, -0.0106],
#         [-0.3913,  0.1274],
#         [ 0.0233,  0.3564],
#         [ 0.1609,  0.2883],
#         [ 0.2037,  0.0646],
#         [-0.0645, -0.2456],
#         [-0.0429, -0.2886],
#         [ 0.0724,  0.0569],
#         [-0.1567, -0.1426],
#         [-0.2259,  0.3199],
#         [ 0.1516, -0.1836],
#         [ 0.3835,  0.3200],
#         [ 0.0763,  0.0204],
#         [ 0.3880,  0.0394],
#         [-0.1733, -0.3000],
#         [ 0.2681, -0.3993],
#         [-0.4190,  0.0696],
#         [ 0.1547,  0.2258],
#         [-0.0094, -0.3019]], requires_grad=True)
# Parameter containing:
# tensor([[ 0.3479],
#         [-0.3080],
#         [ 0.1248],
#         [ 0.2835],
#         [ 0.2140],
#         [-0.4279],
#         [ 0.2963],
#         [ 0.2259],
#         [-0.0761],
#         [-0.3013],
#         [ 0.2787],
#         [ 0.1277],
#         [-0.0622],
#         [-0.0040],
#         [ 0.0259],
#         [-0.0146],
#         [ 0.1663],
#         [-0.0796],
#         [ 0.2617],
#         [ 0.3697]], requires_grad=True)
# Parameter containing:
# tensor([-0.3112,  0.3610, -0.1798,  0.0022, -0.0591, -0.0231,  0.2026, -0.1902,
#          0.3990, -0.4415, -0.3148, -0.1915,  0.1542, -0.2951,  0.4014, -0.2848,
#         -0.1266,  0.2724, -0.3488, -0.1687], requires_grad=True)
# Parameter containing:
# tensor([ 0.2524, -0.2880, -0.1320,  0.0226, -0.3236,  0.1919, -0.1666, -0.1941,
#         -0.0574,  0.1411, -0.2392, -0.1042, -0.2915,  0.4465, -0.4389, -0.0092,
#          0.0170,  0.3931,  0.4391,  0.3458], requires_grad=True)
# Parameter containing:
# tensor([[ 0.2172, -0.3990, -0.1638, -0.3145,  0.1029]], requires_grad=True)
# Parameter containing:
# tensor([1.], requires_grad=True)
# Parameter containing:
# tensor([0.], requires_grad=True)

# %%
x = torch.load(f"C:/Users/Marc/Desktop/network/network_LSTM-510.pt", map_location='cpu')
x
# Out:
# OrderedDict([('lstm.weight_ih_l0',
#               tensor([[ 9.5604e-01],
#                       [-2.7282e-01],
#                       [-6.0851e-01],
#                       [-7.6993e-01],
#                       [ 1.1170e+00],
#                       [ 9.4927e-01],
#                       [ 1.4081e+00],
#                       [ 7.1743e-01],
#                       [ 2.6803e-01],
#                       [ 8.7604e-01],
#                       [-1.5671e-03],
#                       [ 9.5805e-01],
#                       [ 1.7373e+00],
#                       [ 5.7856e-01],
#                       [ 1.9273e-01],
#                       [-3.7190e-01],
#                       [ 1.2352e+00],
#                       [ 1.0384e+00],
#                       [-7.7336e-01],
#                       [-3.9639e-01]])),
#              ('lstm.weight_hh_l0',
#               tensor([[-0.0127],
#                       [-0.5819],
#                       [ 0.4052],
#                       [-0.2645],
#                       [ 0.5958],
#                       [ 1.3224],
#                       [ 1.0717],
#                       [ 1.0647],
#                       [-0.5226],
#                       [ 0.4872],
#                       [-0.3870],
#                       [-0.1755],
#                       [ 0.2668],
#                       [-0.6935],
#                       [-0.4310],
#                       [ 1.6073],
#                       [ 1.3843],
#                       [ 0.9479],
#                       [-0.4458],
#                       [ 1.7140]])),
#              ('lstm.bias_ih_l0',
#               tensor([-0.0204,  0.1013, -1.0839, -0.2285,  0.5610,  1.2406,  0.3476, -0.2490,
#                       -0.2261,  0.3147, -0.3567,  0.4200, -0.1351, -0.2050, -0.7695, -0.1376,
#                       -0.5339, -0.7854, -0.4354,  0.3343])),
#              ('lstm.bias_hh_l0',
#               tensor([-0.0556, -0.4213, -0.3166, -0.0079,  1.0107,  0.6574,  0.5611,  0.0418,
#                        0.4927,  0.4262, -0.9251,  0.1441,  0.0217, -0.5992, -0.8060,  0.2038,
#                       -0.5677, -1.0124,  0.1348,  0.4868])),
#              ('lstm.weight_hr_l0',
#               tensor([[-0.6594,  1.6689,  0.6340,  0.3395, -1.0574]])),
#              ('lstm.weight_ih_l0_reverse',
#               tensor([[ 0.6456],
#                       [ 0.6650],
#                       [ 0.2553],
#                       [ 1.3184],
#                       [-0.4232],
#                       [-0.8919],
#                       [-0.7127],
#                       [ 0.6647],
#                       [-0.5699],
#                       [-0.3976],
#                       [-1.1938],
#                       [-0.4469],
#                       [-0.8871],
#                       [-0.2134],
#                       [-1.2958],
#                       [-0.5859],
#                       [-0.9584],
#                       [ 0.5818],
#                       [ 1.2495],
#                       [-0.3058]])),
#              ('lstm.weight_hh_l0_reverse',
#               tensor([[ 0.7401],
#                       [ 0.8379],
#                       [ 2.5354],
#                       [ 0.6404],
#                       [ 0.6336],
#                       [-0.1150],
#                       [-0.1017],
#                       [ 1.3572],
#                       [ 2.3918],
#                       [ 0.0406],
#                       [ 1.6879],
#                       [ 2.6965],
#                       [-1.0014],
#                       [ 2.4753],
#                       [-2.9329],
#                       [-1.2580],
#                       [-0.5926],
#                       [ 1.7712],
#                       [ 0.9152],
#                       [ 0.4595]])),
#              ('lstm.bias_ih_l0_reverse',
#               tensor([ 0.2049, -0.0904, -0.7607,  0.7262, -0.7340,  1.5245,  2.3120,  0.9988,
#                        1.5919, -0.3861, -0.6585,  0.2314, -1.1859,  0.4462,  0.4516,  1.7487,
#                        1.6387,  1.2146,  1.5279, -0.0625])),
#              ('lstm.bias_hh_l0_reverse',
#               tensor([-0.0794,  0.2130, -0.9343,  0.6201, -0.8695,  1.9244,  2.3389,  1.3939,
#                        1.6819, -0.4755,  0.0613, -0.1721, -0.7902,  0.2510,  0.8149,  1.2810,
#                        2.0542,  1.2195,  1.3246, -0.3276])),
#              ('lstm.weight_hr_l0_reverse',
#               tensor([[ 1.5665,  1.8515, -0.2700,  1.5150, -0.7513]])),
#              ('lstm.weight_ih_l1',
#               tensor([[ 1.4456e+00,  1.6030e+00],
#                       [-2.4169e-01,  1.6053e+00],
#                       [ 4.7337e-01,  1.0955e+00],
#                       [-1.2362e-01,  1.2667e+00],
#                       [ 2.4161e+00,  5.3808e-01],
#                       [-1.8692e-01,  4.0674e+00],
#                       [-7.1603e-02,  1.4511e+00],
#                       [ 6.3979e-01,  1.3188e+00],
#                       [-4.5362e-01,  1.0678e+00],
#                       [ 2.9250e+00, -1.1072e-01],
#                       [-9.4606e-01, -1.1712e+00],
#                       [ 1.0741e-01, -8.8121e-01],
#                       [-6.6315e-01, -8.0813e-01],
#                       [-8.1288e-01, -6.8462e-01],
#                       [-9.1719e-02, -8.1482e-01],
#                       [ 1.9653e-04,  5.0454e-01],
#                       [-9.2762e-01,  1.5947e+00],
#                       [ 8.4840e-02,  1.1563e+00],
#                       [-4.6815e-01,  1.3604e+00],
#                       [ 3.1611e+00, -1.9491e+00]])),
#              ('lstm.weight_hh_l1',
#               tensor([[-1.2721],
#                       [ 0.1126],
#                       [ 0.1910],
#                       [-0.4831],
#                       [-0.4869],
#                       [ 0.3330],
#                       [ 0.2507],
#                       [ 0.6062],
#                       [-0.7391],
#                       [-0.2382],
#                       [-0.6032],
#                       [ 0.9732],
#                       [ 0.4333],
#                       [ 0.2459],
#                       [ 1.3823],
#                       [ 0.3352],
#                       [-0.1738],
#                       [-0.3097],
#                       [-0.2188],
#                       [-1.5860]])),
#              ('lstm.bias_ih_l1',
#               tensor([-0.5972, -0.5041, -0.1432, -0.4131, -1.7268,  1.6587,  0.7260,  0.0840,
#                        0.1682, -1.5427,  0.8761,  0.2291, -0.3047, -0.0248,  0.8616,  0.5428,
#                       -0.0447, -0.2648, -0.0027,  1.0665])),
#              ('lstm.bias_hh_l1',
#               tensor([-0.7093, -0.5958, -0.2603, -0.0864, -1.3785,  1.3349, -0.0024,  0.1583,
#                       -0.3487, -1.7396,  0.1117,  0.2908, -0.1619, -0.0621,  0.5455,  0.7633,
#                        0.1690, -0.0190,  0.0149,  1.1671])),
#              ('lstm.weight_hr_l1',
#               tensor([[ 0.6171, -0.2655, -0.2091, -0.3290,  1.2100]])),
#              ('lstm.weight_ih_l1_reverse',
#               tensor([[ 0.1053,  1.0883],
#                       [-2.0509,  1.3577],
#                       [-0.0353, -1.2583],
#                       [-0.5656,  0.7656],
#                       [-0.4836, -0.9757],
#                       [ 0.2020,  0.6441],
#                       [-0.7879,  1.6908],
#                       [ 0.7743, -1.1265],
#                       [-0.0296,  1.7232],
#                       [ 0.2844,  2.4034],
#                       [-0.2911,  0.8066],
#                       [-0.0243,  0.9547],
#                       [-0.2002,  0.9184],
#                       [-0.3733, -0.2351],
#                       [ 0.6850,  0.3364],
#                       [ 0.1620,  0.6620],
#                       [-1.2681,  1.2889],
#                       [ 0.2320,  1.5374],
#                       [-0.9892,  1.5637],
#                       [-3.3855,  2.1968]])),
#              ('lstm.weight_hh_l1_reverse',
#               tensor([[-0.1524],
#                       [ 0.8377],
#                       [ 0.5185],
#                       [-0.3010],
#                       [ 0.2421],
#                       [-0.0561],
#                       [ 0.5064],
#                       [-0.6151],
#                       [-0.2640],
#                       [ 0.1419],
#                       [ 0.1229],
#                       [ 0.1286],
#                       [-0.3145],
#                       [-0.9674],
#                       [ 0.7087],
#                       [ 0.7453],
#                       [-0.0869],
#                       [ 1.2620],
#                       [-0.3598],
#                       [ 0.6219]])),
#              ('lstm.bias_ih_l1_reverse',
#               tensor([-0.0833, -0.4473,  0.4745,  0.5179,  0.4354, -0.0991,  0.6309,  0.3316,
#                        0.5075,  1.9165,  0.0290, -0.6797, -0.6267,  0.2443,  0.0379, -0.4601,
#                       -0.0646, -1.1910, -0.2440,  0.5055])),
#              ('lstm.bias_hh_l1_reverse',
#               tensor([-0.6769, -0.1687,  0.5897,  0.5446,  0.7002, -0.5158,  1.1579,  0.5703,
#                        1.0688,  1.4581,  0.0180, -0.0496, -0.2786,  0.3107, -0.3797, -0.0195,
#                        0.5004, -1.2978,  0.0443,  0.2398])),
#              ('lstm.weight_hr_l1_reverse',
#               tensor([[ 0.3930,  0.3039, -0.6739, -0.5025,  0.5947]]))])

# %%
batch_size = 10
device = "cpu"

model = LSTM_net(batch_size=batch_size, device=device).to(device)
x = torch.load(f"C:/Users/Marc/Desktop/network/network_LSTM-510.pt", map_location='cpu')
model.load_state_dict(x)
model.to(device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [11], in <cell line: 6>()
#       4 model = LSTM_net(batch_size=batch_size, device=device).to(device)
#       5 x = torch.load(f"C:/Users/Marc/Desktop/network/network_LSTM-510.pt", map_location='cpu')
# ----> 6 model.load_state_dict(x)
#       7 model.to(device)
#
# File ~\anaconda3\envs\deep\lib\site-packages\torch\nn\modules\module.py:1497, in Module.load_state_dict(self, state_dict, strict)
#    1492         error_msgs.insert(
#    1493             0, 'Missing key(s) in state_dict: {}. '.format(
#    1494                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    1496 if len(error_msgs) > 0:
# -> 1497     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1498                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    1499 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for LSTM_net:
# 	Missing key(s) in state_dict: "norm.weight", "norm.bias", "norm.running_mean", "norm.running_var".

# %%
out = model(ind)

# %%
batch_size = 1
device = "cpu"

model = LSTM_net(batch_size=batch_size, device=device).to(device)

x = torch.load(r"C:\Users\Marc\Desktop\Wierd output\net.pt", map_location='cpu')
model.load_state_dict(x)
model.to(device)

# %%
out = model(ind[0].view(1, 1, -1))

# %%
out

# %%
for i in model.parameters():
    print(i)

# %%
batch_size = 1
device = "cpu"

model = LSTM_net(batch_size=batch_size, device=device).to(device)

# %%
ind[0].view(1, 1, -1)

# %%
model(ind[0].view(1, 1, -1))

# %%
model(ind[1].view(1, 1, -1))

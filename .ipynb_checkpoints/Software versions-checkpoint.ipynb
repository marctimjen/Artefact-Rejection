# %%
conda list
# Out:
# # packages in environment at C:\Users\Marc\anaconda3\envs\art:
# #
# # Name                    Version                   Build  Channel
# anyio                     3.6.1            py39hcbf5309_0    conda-forge
# aom                       3.3.0                h0e60522_1    conda-forge
# appdirs                   1.4.4              pyh9f0ad1d_0    conda-forge
# argon2-cffi               21.3.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      21.2.0           py39hb82d6ee_2    conda-forge
# asttokens                 2.0.5              pyhd8ed1ab_0    conda-forge
# attrs                     21.4.0             pyhd8ed1ab_0    conda-forge
# babel                     2.10.1             pyhd8ed1ab_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                        py_2    conda-forge
# backports.functools_lru_cache 1.6.4              pyhd8ed1ab_0    conda-forge
# ...

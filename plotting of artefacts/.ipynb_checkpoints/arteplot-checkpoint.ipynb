# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
path = r"C:\Users\Marc\Desktop\old"

# %% [markdown]
# Read the data from the validation set:

# %%
ind = np.memmap(path + "/model_input.dat", dtype='float32', mode='r', shape=(28, 22, 549200))
#target = np.memmap(path + "/model_target.dat", dtype='float32', mode='r', shape=(28, 22, 549200))

# %% [markdown]
# Create a dataframe with the specific channel:

# %% [markdown]
# Plot an example of ELPP:

# %%
df = pd.DataFrame({'eeg':ind[1][0]}) # using channel FP1-F7 from 00000254_s007_t000

delta = 2 # add two seconds before and after the artefact.

st, en = 653.9959,655.0095

(art_start, art_end) = (math.floor((st)*200), math.ceil((en)*200))
(start, end) = (math.floor((st-delta)*200), math.ceil((en+delta)*200))
index = range(start, end)
one = df["eeg"][start:end]
two = df["eeg"][art_start:art_end]

one.plot(label = "FP1-F7")
two.plot(color = "r", label = "")
plt.title("Example of elpp")
plt.xlabel('sample number')
plt.ylabel('µV')
plt.tight_layout(pad=5.0)
plt.legend()
plt.savefig(f"C:/Users/Marc/Desktop/Figurer/elpp.jpg", bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# Plot an example fo eye momevement

# %%
df = pd.DataFrame({'eeg':ind[1][0]}) # using channel FP1-F7 from 00000254_s007_t000
delta = 2
st, en = 230, 233
# st, en = 268, 270
# st, en = 563, 564


(art_start, art_end) = ((st)*200, (en)*200)
(start, end) = ((st-delta)*200, (en+delta)*200)
index = range(start, end)
one = df["eeg"][start:end]
two = df["eeg"][art_start:art_end]

# %%
one.plot(label = "FP1-F7")
two.plot(color = "r", label = "")
plt.title("Example of eyem")
plt.xlabel('sample number')
plt.ylabel('µV')
plt.tight_layout(pad=5.0)
plt.legend()
plt.savefig(f"C:/Users/Marc/Desktop/Figurer/eyem.jpg", bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# An example of elec

# %%
df = pd.DataFrame({'eeg':ind[1][1]}) # using data from 00000254_s007_t000

delta = 2 # add two seconds before and after the artefact.
# st, en = 64.9899, 69.0148
st, en = 126.0154, 132.0083

(art_start, art_end) = (math.floor((st)*200), math.ceil((en)*200))
(start, end) = (math.floor((st-delta)*200), math.ceil((en+delta)*200))
index = range(start, end)
one = df["eeg"][start:end]
two = df["eeg"][art_start:art_end]

one.plot(label = "F7-T3")
two.plot(color = "r", label = "")
plt.title("Example of elec")
plt.xlabel('sample number')
plt.ylabel('µV')
plt.tight_layout(pad=5.0)
plt.legend()
plt.savefig(f"C:/Users/Marc/Desktop/Figurer/elec.jpg", bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# Example of Musc

# %%
df = pd.DataFrame({'eeg':ind[1][1]}) # using channel F7-T3 data from 00000254_s007_t000

delta = 1 # add one seconds before and after the artefact.
st, en = 306.0403,310.8477

(art_start, art_end) = (math.floor((st)*200), math.ceil((en)*200))
(start, end) = (math.floor((st-delta)*200), math.ceil((en+delta)*200))
index = range(start, end)
one = df["eeg"][start:end]
two = df["eeg"][art_start:art_end]

one.plot(label = "F7-T3")
two.plot(color = "r", label = "")
plt.title("Example of musc")
plt.xlabel('sample number')
plt.ylabel('µV')
plt.tight_layout(pad=5.0)
plt.legend()
plt.savefig(f"C:/Users/Marc/Desktop/Figurer/musc.jpg", bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# Example of chew

# %%
df = pd.DataFrame({'eeg':ind[6][0]}) # using channel FP1-F7 from 00003465_s004_t001

delta = 2 # add two seconds before and after the artefact.
# st, en = 64.9899, 69.0148
st, en = 958.9474,959.3461

(art_start, art_end) = (math.floor((st)*200), math.ceil((en)*200))
(start, end) = (math.floor((st-delta)*200), math.ceil((en+delta)*200))
index = range(start, end)
one = df["eeg"][start:end]
two = df["eeg"][art_start:art_end]

one.plot(label = "FP1-F7")
two.plot(color = "r", label = "")
plt.title("Example of chew")
plt.xlabel('sample number')
plt.ylabel('µV')
plt.tight_layout(pad=5.0)
plt.legend()
plt.savefig(f"C:/Users/Marc/Desktop/Figurer/chew.jpg", bbox_inches='tight')
plt.show()
plt.close()

# %% [markdown]
# Example of eyem_musc

# %%
df = pd.DataFrame({'eeg':ind[1][0]}) # using channel FP1-F7 from 00000254_s007_t000

delta = 2
st, en = 752.0059,770.0024

(art_start, art_end) = (math.floor((st)*200), math.ceil((en)*200))
(start, end) = (math.floor((st-delta)*200), math.ceil((en+delta)*200))
index = range(start, end)
one = df["eeg"][start:end]
two = df["eeg"][art_start:art_end]

one.plot(label = "FP1-F7")
two.plot(color = "r", label = "")
plt.title("Example of eyem_musc")
plt.xlabel('sample number')
plt.ylabel('µV')
plt.tight_layout(pad=5.0)
plt.legend()
plt.savefig(f"C:/Users/Marc/Desktop/Figurer/eyem_musc.jpg", bbox_inches='tight')
plt.show()
plt.close()
